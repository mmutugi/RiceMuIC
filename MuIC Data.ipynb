# %%
#This is the plotting code

# %%
#Starts by importing the Root lIbrary

# %%
import ROOT

# %%
from ROOT import TFile

#root_file=TFile.Open('muic10Tev10000events6.3eta.root','READ')
#root_file=TFile.Open('muic10TeV1000events6.3eta.root','READ')
root_file=TFile.Open('muic10TeV4.4eta1000events.root','READ')
#root_file=TFile.Open('muic10TeV3.5eta1000events.root','READ')
#root_file=TFile.Open('muic10TeV5.8eta1000events.root','READ')
################################################################
#root_file=TFile.Open('muic100events3.5Tungsten.root','READ')

#root_file=TFile.Open('muic100GeV4.4etaTungsten.root','READ')

#root_file=TFile.Open('muic100GeV5.8eta.root','READ')

#root_file=TFile.Open('muic100Gev6.3etaTungsten.root','READ')

###############################################################

#oot_file=TFile.Open('muic1TeV10000events4.4eta.root','READ')

#root_file=TFile.Open('muic1TeV10000events5.7eta.root','READ')

#root_file=TFile.Open('muic1TeV10000events6.3eta.root','READ')

#root_file=TFile.Open('muic1TeV1000events3.5eta.root','READ')

################################################################

#root_file=TFile.Open('muic100GeV10000events6.3eta.root','READ')

#root_file=TFile.Open('muic100Gev10000events4.4eta.root','READ')

#root_file=TFile.Open('muic100Gev10000events3.5eta.root','READ')

################################################################

#root_file=TFile.Open('muic500GeV1000events6.3eta.root','READ')

#root_file=TFile.Open('muic500GeV10000events4.4eta.root','READ')

#root_file=TFile.Open('muic500Gev10000events3.5eta.root','READ')

#root_file=TFile.Open('muic500GeV5.8eta10000events.root','READ')

#############################################################

#root_file=TFile.Open('muic750Gev10000events6.3eta.root','READ')

#root_file=TFile.Open('muic750GeV10000events3.5eta.root','READ')

#root_file=TFile.Open('muic750GeV10000events4.4eta.root','READ')

#root_file=TFile.Open('muic750GeV5.8eta10000events.root','READ')

############################################################3

#root_file=TFile.Open('muic250TeV10000events6.3eta.root','READ')

#root_file=TFile.Open('muic250GeV1000events4.4eta.root','READ')

#root_file=TFile.Open('muic250GeV10000events3.5eta.root','READ')

#root_file=TFile.Open('muic25OC0GeV5.8eta10000events.root','READ')

################################################################

#root_file=TFile.Open('muic2Tev1000events3.5eta.root','READ')

#root_file=TFile.Open('muic2TeV1000events4.4eta.root','READ')

#root_file=TFile.Open('muic2Tev1000events5.8eta.root','READ')

#root_file=TFile.Open('muic2TeV1000events6.3eta.root','READ')

#***************************************************************#

#root_file=TFile.Open('muicW4TeV4.4eta.root','READ')

#root_file=TFile.Open('muicW5TeV4.4eta.root','READ')

#root_file=TFile.Open('muicW7.5TeV4.4eta.root','READ')

############################################################## Iron

#root_file=TFile.Open('muicFe1TeV4.4eta.root','READ')
#root_file=TFile.Open('muicFe2TeV4.4eta.root','READ')
#root_file=TFile.Open('muicFe750GeV4.4eta.root','READ')
#root_file=TFile.Open('muicFe250GeV4.4eta.root','READ')
#root_file=TFile.Open('muicFe500GeV4.4eta.root','READ')

#root_file=TFile.Open('muicFe10TeV4.4eta.root','READ')
#root_file=TFile.Open('muic1004.4.root','READ')

#root_file=TFile.Open('muicFe5TeV4.4eta.root','READ')
#root_file=TFile.Open('muicFe7.5eta.root','READ')
#root_file=TFile.Open('muicFe4TeV4.4eta.root','READ')

#BRASS
#oot_file=TFile.Open('muicBRASS4.4eta100GeV.root','READ')
#root_file=TFile.Open('muicBRASS4.410Tev.root','READ')
#root_file=TFile.Open('muicBRASS4.4eta1TeV.root','READ')
#root_file=TFile.Open('muicBRASS4.4eta250GeV.root','READ')
#root_file=TFile.Open('muicBRASS4.4eta2TeV.root','READ')
#root_file=TFile.Open('muicBRASS4.4eta4TeV.root','READ')
#root_file=TFile.Open('muicBRASS4.4eta500GeV.root','READ')
#root_file=TFile.Open('muicBRASS4.4eta5TeV.root','READ')
#root_file=TFile.Open('muicBRASS4.4eta7.5TeV.root','READ')
#root_file=TFile.Open('muicBRASS4.4eta750GeV.root','READ')

#CONCRETE
#root_file=TFile.Open('muicCONCRETE4.4eta750GeV.root','READ')
#root_file=TFile.Open('muicCONCRETE4.4eta7.5Tev.root','READ')
#root_file=TFile.Open('muicCONCRETE4.4eta250GeV.root','READ')
#root_file=TFile.Open('muicCONCRETE4.4eta500GeV.root','READ')
#root_file=TFile.Open('muicCONCRETE4.4eta1TeV.root','READ')
#root_file=TFile.Open('muicCONCRETE4.4eta2TeV.root','READ')
#root_file=TFile.Open('muicCONCRETE4.4eta4TeV.root','READ')
#root_file=TFile.Open('muicCONCRETE4.4eta5TeV.root','READ')
#root_file=TFile.Open('muicCONCRETE4.410TeV.root','READ')
#root_file=TFile.Open('MUICCONCRETE4.4ETA100GEV.root','READ')





beam_energy=10000

for branch in root_file.events.GetListOfBranches():
    print (branch.GetName())
# Out:
# vsize_gen
# gen_e_before_nozzle
# gen_e_after_nozzle
# gen_e_deposited_nozzle
# gen_phi_before_nozzle
# gen_phi_after_nozzle
# gen_phi_scatter
# gen_eta_before_nozzle
# gen_eta_after_nozzle
# gen_eta_scatter
# gen_position_phi_before_nozzle
# gen_position_phi_after_nozzle
# gen_position_eta_before_nozzle
# gen_position_eta_after_nozzle
# gen_position_phi_scattering
# gen_position_eta_scattering
# theta_before_nozzle
# theta_after_nozzle
# position_theta_before_nozzle
# position theta after nozzle
# theta_scatter
# position_theta_scatter

# %%
from ROOT import TH1F, TLegend, TObject, TPaveText
import numpy as np
from ROOT import TCanvas

line_id = 0

eta_scatter_hist =TH1F ('eta scattering', 'GEN #Delta #eta', 100,-0.01,0.01)

for event in root_file.events:
    for gen_id in range (event. vsize_gen):
        eta_scatter = event.gen_eta_scatter[gen_id]
        
        eta_scatter_hist.Fill(eta_scatter)
        line_id +=1
canvas = TCanvas ('eta scatter', 'GEN #eta')
canvas.cd(0)

eta_scatter_hist.Fit ("gaus","","")

Const = eta_scatter_hist.GetFunction("gaus").GetParameter(0);
Mean = eta_scatter_hist.GetFunction("gaus").GetParameter(1);
Sigma = eta_scatter_hist.GetFunction("gaus").GetParameter(2);

Const= round(Const,2)
Mean = round(Mean, 2)
Sigma = round (Sigma, 2)


legend = TPaveText(-1, 500, -3, 580)
legend.AddText(f"Const:{Const}")
legend.AddText(f"Mean: {Mean}")
legend.AddText(f"Standard dev: {Sigma}")

eta_scatter_hist.Draw('')
canvas.Draw('')
legend.Draw('')
# Out:
#  FCN=63.5288 FROM MIGRAD    STATUS=CONVERGED      60 CALLS          61 TOTAL
#                      EDM=3.38132e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     2.74060e+01   1.17433e+00   3.53305e-03   4.23222e-04
#    2  Mean        -5.56581e-06   9.18534e-05   3.56851e-07  -6.42965e+00
#    3  Sigma        2.70957e-03   7.76999e-05   2.78345e-05  -2.11594e-02
# Warning in <TFile::Append>: Replacing existing TH1: eta scattering (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: eta scatter

# %%
from ROOT import TH1F, TLegend, TObject, TPaveText,TMath,TF1
import numpy as np
from ROOT import TCanvas

line_id = 0


energy_deposit_hist =TH1F ('energy_deposited', 'GEN #Delta E',100, 0,beam_energy)

for event in root_file.events:
    for gen_id in range (event.vsize_gen):
        gen_e_deposited_nozzle = event.gen_e_deposited_nozzle[gen_id]
        
        energy_deposit_hist.Fill(gen_e_deposited_nozzle)
             
        line_id +=1
        
        #beam_energy=event.gen_e_before_nozzle

canvas =TCanvas ('gen_e_energy_deposited', 'GEN #Delta #E')
canvas.cd(0)
energy_deposit_hist.Fit("landau", "","")

#X=1
Const = energy_deposit_hist.GetFunction("landau").GetParameter(0);
Most Probable Value = energy_deposit_hist.GetFunction("landau").GetParameter(1);
Sigma = energy_deposit_hist.GetFunction("landau").GetParameter(2);

weighted_func = TF1("weighted_func","x*TMath::Landau(x,[0],[1])",0,beam_energy)
weighted_func.SetParameter(0,Mean)
weighted_func.SetParameter(1,Sigma)
dist_func= TF1("dist_func","TMath::Landau(x,[0],[1])",0, beam_energy)
dist_func.SetParameter(0,Mean)
dist_func.SetParameter(1,Sigma)
weighted_int = weighted_func.Integral((20/100)*beam_energy,beam_energy)
dist_int = dist_func.Integral((20/100)*beam_energy, beam_energy)

avg_loss_tail = weighted_int/dist_int

print(avg_loss_tail)


energy_deposit_hist.GetXaxis().SetTitle("E")



Const= round(Const,3)
Mean = round(Mean, 3)
Sigma = round (Sigma,3)



legend = TPaveText(1400, 40, 5000, 60)
legend.AddText(f"Const:{Const}")
legend.AddText(f"Mean: {Most Probable Value}")
legend.AddText(f"Standard dev: {Sigma}")


energy_deposit_hist.Draw('')
legend.Draw('')
canvas.Draw('')
# Out:
# 3556.3209546575035
#  FCN=68.2964 FROM MIGRAD    STATUS=CONVERGED     165 CALLS         166 TOTAL
#                      EDM=7.67445e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     5.25045e+02   2.60285e+01   6.99189e-02   1.77101e-05
#    2  MPV          8.98852e+02   1.28442e+01   4.41803e-02   2.04284e-05
#    3  Sigma        1.83311e+02   7.10719e+00   1.05217e-05   7.42463e-02
# Warning in <TFile::Append>: Replacing existing TH1: energy_deposited (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: gen_e_energy_deposited

# %%
from ROOT import TH1F,TPaveText
import numpy as np
from ROOT import TCanvas

# %%
line_id = 0

theta_scatter_hist =TH1F ('Theta scatter', 'GEN #Delta #theta', 100,-0.0003,0.0003)

for event in root_file.events:
    for gen_id in range (event. vsize_gen):
        
        theta_scatter = event.theta_scatter[gen_id]
        
        theta_scatter_hist.Fill(theta_scatter)
        line_id +=1
canvas = TCanvas ('theta scatter', 'GEN #Theta')
canvas.cd(0)

theta_scatter_hist.Fit ("gaus","","")

Const = theta_scatter_hist.GetFunction("gaus").GetParameter(0);
Mean = theta_scatter_hist.GetFunction("gaus").GetParameter(1);
Sigma = theta_scatter_hist.GetFunction("gaus").GetParameter(2);

Const= round(Const,1)
Mean = round(Mean, 2)
Sigma = round (Sigma, 2)

#print(const, mean, sigma)

legend = TPaveText(-1, 500, -3, 580)
legend.AddText(f"Const:{Const}")
legend.AddText(f"Mean: {Mean}")
legend.AddText(f"Standard dev: {Sigma}")

theta_scatter_hist.Draw('')
canvas.Draw('')
legend.Draw('')
# Out:
#  FCN=60.1445 FROM MIGRAD    STATUS=CONVERGED      60 CALLS          61 TOTAL
#                      EDM=5.42194e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     3.32225e+01   1.40622e+00   4.15249e-03   6.91174e-05
#    2  Mean         9.50144e-07   2.28848e-06   8.58132e-09   1.36936e+02
#    3  Sigma        6.75044e-05   1.87262e-06   2.60910e-05   1.04184e-02
# Warning in <TFile::Append>: Replacing existing TH1: Theta scatter (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: theta scatter

# %%
line_id = 0
phi_scatter_hist =TH1F ('phi scattering', 'GEN #Delta #phi', 100,-0.5,0.5)



for event in root_file.events:
    for gen_id in range (event. vsize_gen):
        
        gen_position_phi_scattering = event.gen_position_phi_scattering[gen_id]
        
        phi_scatter_hist.Fill(gen_position_phi_scattering)
        line_id +=1
canvas = TCanvas ('phi scattering', 'GEN #Delta #phi')
canvas.cd(0)

phi_scatter_hist.Fit ("gaus","","")

Const = phi_scatter_hist.GetFunction("gaus").GetParameter(0);
Mean = phi_scatter_hist.GetFunction("gaus").GetParameter(1);
Sigma = phi_scatter_hist.GetFunction("gaus").GetParameter(2);

Const= round(Const,3)
Mean = round(Mean, 3)
Sigma = round (Sigma, 3)

#print(const, mean, sigma)

legend = TPaveText(-1, 500, -3, 580)
legend.AddText(f"Const:{Const}")
legend.AddText(f"Mean: {Mean}")
legend.AddText(f"Standard dev: {Sigma}")

phi_scatter_hist.Draw('')
canvas.Draw('')
legend.Draw('')
# Out:
#  FCN=41.5227 FROM MIGRAD    STATUS=CONVERGED      60 CALLS          61 TOTAL
#                      EDM=3.56641e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     4.51223e+01   1.84221e+00   4.64791e-03   8.76719e-06
#    2  Mean        -1.32079e-03   2.81482e-03   8.95254e-06   6.98151e-04
#    3  Sigma        8.49763e-02   2.21415e-03   2.14801e-05  -1.57549e-03
# Warning in <TFile::Append>: Replacing existing TH1: phi scattering (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: phi scattering

# %% [markdown]
# from ROOT import TH1F
# import numpy as np
# from ROOT import TCanvas
#
# event_id = 0
#
# bin_edges = np.arange (-np.pi,np.pi,0.01*np.pi)
# bin_count = len(bin_edges)-1
#
# energy_deposit_count_hist =TH1F ('energy_deposited_count', '',bin_count, bin_edges)
# energy_deposit_sum_hist =TH1F ('energy_deposited_avg2', '',bin_count, bin_edges)
#
# for event in root_file.events:
#     for gen_id in range (event.vsize_gen):
#         gen_e_before_nozzle = event.gen_e_before_nozzle[gen_id]
#         gen_e_after_nozzle = event.gen_e_after_nozzle[gen_id]
#         gen_e_deposited_nozzle = event.gen_e_deposited_nozzle[gen_id]
#         gen_position_phi_scattering = event.gen_position_phi_scattering[gen_id]
#
#         #if line_id <10:
#             #print (gen_id, gen_e_before_nozzle,gen_e_after_nozzle,gen_e_deposited_nozzle)
#         energy_deposit_sum_hist.Fill(gen_position_phi_scattering, gen_e_deposited_nozzle)
#         energy_deposit_count_hist.Fill(gen_position_phi_scattering,1)
#
#         line_id +=1
# energy_deposit_sum_hist.Divide(energy_deposit_count_hist)
# energy_deposit_sum_hist.GetXaxis().SetTitle('GEN #Delta #phi')
# energy_deposit_sum_hist.GetYaxis().SetTitle ('Gen #Delta E>')
#
# canvas =TCanvas ('gen_e_energy_deposited', 'GEN #Delta E')
# canvas.cd(0)
# canvas.SetLogy(1)
# energy_deposit_sum_hist.Draw('HIST')
# canvas.Draw('')

# %% [markdown]
# from ROOT import TH2F
# import numpy as np
# from ROOT import TCanvas
#
# event_id = 0
#
# x_bin_edges= np.arange (-1., 1., 0.01)
# x_bin_count= int(len(x_bin_edges)-1)
#
# y_bin_edges= np.arange (0., 1000. ,10.)
# y_bin_count= int(len(y_bin_edges)-1)
#
#
# energy_deposit_hist =TH2F ('energy_deposited_count', '',x_bin_count, x_bin_edges,y_bin_count, y_bin_edges)
# #energy_deposit_sum_hist =TH1F ('energy_deposited_avg2', '',x_bin_count, x_bin_edges,y_bin_edges, y_bin_count)
#
# for event in root_file.events:
#     for gen_id in range (event.vsize_gen):
#         gen_e_before_nozzle = event.gen_e_before_nozzle[gen_id]
#         gen_e_after_nozzle = event.gen_e_after_nozzle[gen_id]
#         gen_e_deposited_nozzle = event.gen_e_deposited_nozzle[gen_id]
#         gen_position_phi_scattering = event.gen_position_phi_scattering[gen_id]
#
#         #if line_id <10:
#             #print (gen_id, gen_e_before_nozzle,gen_e_after_nozzle,gen_e_deposited_nozzle)
#         energy_deposit_hist.Fill(gen_position_phi_scattering, gen_e_deposited_nozzle)
#         #nergy_deposit_count_hist.Fill(gen_position_phi_scattering,1)
#
#         line_id +=1
# #energy_deposit_sum_hist.Divide(energy_deposit_count_hist)
# energy_deposit_hist.GetXaxis().SetTitle('GEN #Delta #phi')
# energy_deposit_hist.GetYaxis().SetTitle ('Gen #Delta E')
#
# canvas =TCanvas ('gen_e_energy_deposited', 'GEN #Delta E')
# canvas.cd(0)
# #canvas.SetLogy(1)
# energy_deposit_hist.Draw('COL')
# canvas.Draw('')

# %% [markdown]
# from ROOT import TH2F
# import numpy as np
# from ROOT import TCanvas
#
# event_id = 0
#
# x_bin_edges= np.arange (-0.1, 0.1, 0.001)
# x_bin_count= int(len(x_bin_edges)-1)
#
# y_bin_edges= np.arange (0., 1200. ,10.)
# y_bin_count= int(len(y_bin_edges)-1)
#
#
# energy_deposit_hist =TH2F ('energy_deposited_count', '',x_bin_count, x_bin_edges,y_bin_count, y_bin_edges)
# #energy_deposit_sum_hist =TH1F ('energy_deposited_avg2', '',x_bin_count, x_bin_edges,y_bin_edges, y_bin_count)
#
# for event in root_file.events:
#     for gen_id in range (event.vsize_gen):
#         gen_e_before_nozzle = event.gen_e_before_nozzle[gen_id]
#         gen_e_after_nozzle = event.gen_e_after_nozzle[gen_id]
#         gen_e_deposited_nozzle = event.gen_e_deposited_nozzle[gen_id]
#         gen_position_eta_scattering = event.gen_position_eta_scattering[gen_id]
#
#         #if line_id <10:
#             #print (gen_id, gen_e_before_nozzle,gen_e_after_nozzle,gen_e_deposited_nozzle)
#         energy_deposit_hist.Fill(gen_position_eta_scattering, gen_e_deposited_nozzle)
#         #nergy_deposit_count_hist.Fill(gen_position_phi_scattering,1)
#
#         line_id +=1
# #energy_deposit_sum_hist.Divide(energy_deposit_count_hist)
# energy_deposit_hist.GetXaxis().SetTitle('GEN #Delta #eta')
# energy_deposit_hist.GetYaxis().SetTitle ('Gen #Delta E')
#
# canvas =TCanvas ('gen_e_energy_deposited', 'GEN #Delta E')
# canvas.cd(0)
# #canvas.SetLogy(1)
# energy_deposit_hist.Draw('COL')
# canvas.Draw('')

# %% [markdown]
# from ROOT import TH2F
# import numpy as np
# from ROOT import TCanvas
#
# event_id = 0
#
# x_bin_edges= np.arange (-1., 1., 0.01)
# x_bin_count= int(len(x_bin_edges)-1)
#
# y_bin_edges= np.arange (0., 1000. ,10.)
# y_bin_count= int(len(y_bin_edges)-1)
#
#
# energy_deposit_hist =TH2F ('energy_deposited_count', '',x_bin_count, x_bin_edges,y_bin_count, y_bin_edges)
# #energy_deposit_sum_hist =TH1F ('energy_deposited_avg2', '',x_bin_count, x_bin_edges,y_bin_edges, y_bin_count)
#
# for event in root_file.events:
#     for gen_id in range (event.vsize_gen):
#         gen_e_before_nozzle = event.gen_e_before_nozzle[gen_id]
#         gen_e_after_nozzle = event.gen_e_after_nozzle[gen_id]
#         gen_e_deposited_nozzle = event.gen_e_deposited_nozzle[gen_id]
#         gen_position_phi_scattering = event.gen_position_phi_scattering[gen_id]
#
#         #if line_id <10:
#             #print (gen_id, gen_e_before_nozzle,gen_e_after_nozzle,gen_e_deposited_nozzle)
#         energy_deposit_hist.Fill(gen_position_phi_scattering, gen_e_deposited_nozzle)
#         #nergy_deposit_count_hist.Fill(gen_position_phi_scattering,1)
#
#         line_id +=1
# #energy_deposit_sum_hist.Divide(energy_deposit_count_hist)
# energy_deposit_hist.GetXaxis().SetTitle('GEN #Delta #phi')
# energy_deposit_hist.GetYaxis().SetTitle ('Gen #Delta E')
#
# canvas =TCanvas ('gen_e_energy_deposited', 'GEN #Delta E')
# canvas.cd(0)
# canvas.SetLogy(1)
# energy_deposit_hist.Draw('COL')
# canvas.Draw('')

# %% [markdown]
# from ROOT import TGraph
# import numpy as np
# from ROOT import TCanvas
#
# event_id = 0
#
# x_arr= list()
# y_arr= list()
#
#
#
#
# #energy_deposit_sum_hist =TH1F ('energy_deposited_avg2', '',x_bin_count, x_bin_edges,y_bin_edges, y_bin_count)
#
# for event in root_file.events:
#     for gen_id in range (event.vsize_gen):
#         gen_e_before_nozzle = event.gen_e_before_nozzle[gen_id]
#         gen_e_after_nozzle = event.gen_e_after_nozzle[gen_id]
#         gen_e_deposited_nozzle = event.gen_e_deposited_nozzle[gen_id]
#         gen_position_phi_scattering = event.gen_position_phi_scattering[gen_id]
#
#         x_arr.append(gen_position_phi_scattering)
#         y_arr.append(gen_e_deposited_nozzle)
#
#
#
#     event_id +=1
#
# n_entries = len(x_arr)
# x_arr = np.asarray(x_arr,dtype= np.float64)
# y_arr = np.asarray(y_arr, dtype = np.float64)
# #print (n_entries, x_arr, y_arr)
#
# #energy_deposit_sum_hist.Divide(energy_deposit_count_hist)
# energy_deposit_scatter = TGraph(n_entries, x_arr, y_arr)
# energy_deposit_scatter.GetXaxis().SetTitle('GEN #Delta #phi')
# energy_deposit_scatter.GetYaxis().SetTitle ('Gen #Delta E')
#
# canvas =TCanvas ('gen_e_energy_deposited', 'GEN #Delta E')
# canvas.cd(0)
# canvas.SetLogy(1)
# energy_deposit_scatter.Draw('AP*')
# canvas.Draw('')

# %% [markdown]
# from ROOT import TGraph
# import numpy as np
# from ROOT import TCanvas
#
# event_id = 0
#
# x_arr= list()
# y_arr= list()
#
#
#
#
# #energy_deposit_sum_hist =TH1F ('energy_deposited_avg2', '',x_bin_count, x_bin_edges,y_bin_edges, y_bin_count)
#
# for event in root_file.events:
#     for gen_id in range (event.vsize_gen):
#         gen_e_before_nozzle = event.gen_e_before_nozzle[gen_id]
#         gen_e_after_nozzle = event.gen_e_after_nozzle[gen_id]
#         gen_e_deposited_nozzle = event.gen_e_deposited_nozzle[gen_id]
#         gen_position_eta_scattering = event.gen_position_eta_scattering[gen_id]
#
#         x_arr.append(gen_position_eta_scattering)
#         y_arr.append(gen_e_deposited_nozzle)
#
#
#
#     event_id +=1
#
# n_entries = len(x_arr)
# x_arr = np.asarray(x_arr,dtype= np.float64)
# y_arr = np.asarray(y_arr, dtype = np.float64)
# #print (n_entries, x_arr, y_arr)
#
# #energy_deposit_sum_hist.Divide(energy_deposit_count_hist)
# energy_deposit_scatter = TGraph(n_entries, x_arr, y_arr)
# energy_deposit_scatter.GetXaxis().SetTitle('GEN #Delta #eta')
# energy_deposit_scatter.GetYaxis().SetTitle ('Gen #Delta E')
#
#
# canvas =TCanvas ('gen_e_energy_deposited', 'GEN #Delta E')
# canvas.cd(0)
# canvas.SetLogy(1)
# energy_deposit_scatter.Draw('AP*')
# canvas.Draw('')
